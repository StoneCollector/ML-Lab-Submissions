# %%
import pandas as pd

df = pd.read_csv('/content/train.csv')

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df = df.drop(['Alley','MasVnrType','MasVnrArea','PoolQC','Fence','MiscFeature','FireplaceQu'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
import pandas as pd

df_train_raw = pd.read_csv('/content/train.csv')
df_test_raw = pd.read_csv('/content/test.csv')

print("Original training data loaded into df_train_raw.")
print("Test data loaded into df_test_raw.")

print("df_train_raw head:")
print(df_train_raw.head())
print("\ndf_test_raw head:")
print(df_test_raw.head())
# Out:
# Original training data loaded into df_train_raw.
# Test data loaded into df_test_raw.
# df_train_raw head:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np

def preprocess_data(df, is_train=True, fitted_preprocessor=None, training_columns=None):
    original_ids = df['Id']


    columns_to_drop = ['Id', 'Alley', 'MasVnrType', 'MasVnrArea', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu']
    existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]
    if existing_columns_to_drop:
        df = df.drop(existing_columns_to_drop, axis=1)

    if is_train:

        y = df['SalePrice']
        X = df.drop('SalePrice', axis=1)


        numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
        categorical_features = X.select_dtypes(include=['object']).columns


        numerical_transformer = SimpleImputer(strategy='median')
        categorical_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
        ])


        preprocessor = ColumnTransformer(
            transformers=[
                ('num', numerical_transformer, numerical_features),
                ('cat', categorical_transformer, categorical_features)
            ])


        X_processed_array = preprocessor.fit_transform(X)
        processed_column_names = preprocessor.get_feature_names_out()


        X_processed = pd.DataFrame(X_processed_array, columns=processed_column_names, index=X.index)


        y_aligned = y.loc[X_processed.index]
        correlation_with_saleprice = X_processed.corrwith(y_aligned)
        low_correlation_features = correlation_with_saleprice[abs(correlation_with_saleprice) < 0.1].index.tolist()

        if low_correlation_features:
            X_processed = X_processed.drop(columns=low_correlation_features)

        final_columns_after_pruning = X_processed.columns.tolist()
        return X_processed, y, preprocessor, final_columns_after_pruning, original_ids

    else:

        X = df.copy()
        if 'SalePrice' in X.columns:
            X = X.drop('SalePrice', axis=1)


        if fitted_preprocessor is None:
            raise ValueError("Fitted preprocessor must be provided for test data preprocessing.")
        if training_columns is None:
            raise ValueError("Training columns must be provided for test data preprocessing.")


        X_processed_array = fitted_preprocessor.transform(X)
        processed_column_names = fitted_preprocessor.get_feature_names_out()
        X_processed = pd.DataFrame(X_processed_array, columns=processed_column_names, index=X.index)


        missing_cols = set(training_columns) - set(X_processed.columns)
        for c in missing_cols:
            X_processed[c] = 0
        X_processed = X_processed[training_columns]

        return X_processed, original_ids

print("Function 'preprocess_data' redefined successfully.")
# Out:
# Function 'preprocess_data' redefined successfully.

# %%
X_preprocessed_df, y_target, fitted_preprocessor, final_training_columns, train_ids = preprocess_data(df_train_raw.copy(), is_train=True)

print("Training data preprocessed successfully.")
print("Shape of X_preprocessed_df:", X_preprocessed_df.shape)
print("Shape of y_target:", y_target.shape)
print("Number of final training columns:", len(final_training_columns))
# Out:
# Training data preprocessed successfully.
# Shape of X_preprocessed_df: (1460, 120)
# Shape of y_target: (1460,)
# Number of final training columns: 120

# %%
X_test_preprocessed, test_ids = preprocess_data(df_test_raw.copy(), is_train=False, fitted_preprocessor=fitted_preprocessor, training_columns=final_training_columns)

print("Test data preprocessed successfully.")
print("Head of the preprocessed test feature DataFrame (X_test_preprocessed):")
print(X_test_preprocessed.head())
print("\nShape of the preprocessed test feature DataFrame:")
print(X_test_preprocessed.shape)
# Out:
# Test data preprocessed successfully.
# Head of the preprocessed test feature DataFrame (X_test_preprocessed):
#    num__LotFrontage  num__LotArea  num__OverallQual  num__YearBuilt  \
# 0              80.0       11622.0               5.0          1961.0
# 1              81.0       14267.0               6.0          1958.0
# 2              74.0       13830.0               5.0          1997.0
# 3              78.0        9978.0               6.0          1998.0
# 4              43.0        5005.0               8.0          1992.0
#
#    num__YearRemodAdd  num__BsmtFinSF1  num__BsmtUnfSF  num__TotalBsmtSF  \
# 0             1961.0            468.0           270.0             882.0
# 1             1958.0            923.0           406.0            1329.0
# 2             1998.0            791.0           137.0             928.0
# 3             1998.0            602.0           324.0             926.0
# 4             1992.0            263.0          1017.0            1280.0
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate the RandomForestRegressor model
# Using a random_state for reproducibility
model = RandomForestRegressor(random_state=42)

# Train the model using the preprocessed features and target labels
model.fit(X_preprocessed_df, y_target)

print("RandomForestRegressor model trained successfully.")
# Out:
# RandomForestRegressor model trained successfully.

# %%
test_predictions = model.predict(X_test_preprocessed)

print("Predictions on test data generated successfully.")
print("First 5 predictions:", test_predictions[:5])
# Out:
# Predictions on test data generated successfully.
# First 5 predictions: [128950.41 155011.84 182915.85 180558.07 198889.06]

# %%
submission_df = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission.csv', index=False)

print("Submission file 'submission.csv' created successfully.")
print("Head of submission_df:")
print(submission_df.head())
# Out:
# Submission file 'submission.csv' created successfully.
# Head of submission_df:
#      Id  SalePrice
# 0  1461  128950.41
# 1  1462  155011.84
# 2  1463  182915.85
# 3  1464  180558.07
# 4  1465  198889.06
